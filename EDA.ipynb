# %%
import pandas as pd

# %%
df = pd.read_csv('Ceny mieszkań.csv', sep=";", encoding='cp1250')
df
# Out:
#   Unnamed: 0 2020 I kwarta¸ 2020 II kwarta¸ 2020 III kwarta¸ 2020 IV kwarta¸  \
# 0     GdaÄsk          8 383           8 480            8 882           8 874
# 1     Gdynia          7 667          7 727Ę            7 996           7 906
# 2      Sopot         11?760          11?700           11?780          12?050
# 3  Wejherowo          4?500           4?600            4?700           4?800
# 4       Reda          5?500           5?600            5?700           5?800
# 5      Rumia          5?500           5?600            5?700           5?800
#
#   2021 I kwarta¸ 2021 II kwarta¸ 2021 III kwarta¸ 2021 IV kwarta¸  \
# 0         9 031Ę           9 071            9 566          10 208
# 1          8 025           8 465            8 775           8 943
# 2         12?200           1?800           13?400          14?100
# 3          5?000           5?200            5?400            5600
# 4          5?900           6?000            6?100           6?200
# ...
